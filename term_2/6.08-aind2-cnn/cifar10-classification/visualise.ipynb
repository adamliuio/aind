# %% [markdown]
# mnist cnn

# %%
results_reverse = {}
results_reverse["acc"]      = [i["acc"]      for i in result]
results_reverse["loss"]     = [i["loss"]     for i in result]
results_reverse["val_acc"]  = [i["val_acc"]  for i in result]
results_reverse["val_loss"] = [i["val_loss"] for i in result]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16, 10))
plt.plot(results_reverse["acc"], label="acc")
plt.plot(results_reverse["loss"], label="loss")
plt.plot(results_reverse["val_acc"], label="val_acc")
plt.plot(results_reverse["val_loss"], label="val_loss")
plt.legend()
plt.title("mnist title")
plt.show()
